# %% [markdown]
# https://www.simplilearn.com/top-python-libraries-for-data-science-article
#
# https://pandas.pydata.org/
#
# https://pandas.pydata.org/docs/user_guide/index.html
#
# https://www.youtube.com/watch?v=_T8LGqJtuGc
#
# https://github.com/wesm/pydata-book
#
# http://www.lac.inpe.br/~rafael.santos/Docs/CAP394/WholeStory-Iris.html
#
# https://pandas.pydata.org/docs/user_guide/10min.html#importing-and-exporting-data
#
# Iris dataset:
# https://github.com/illinois-cse/data-fa14/blob/gh-pages/data/iris.csv

# %% [markdown]
# # Investigation of the Iris Dataset using Pandas

# %% [markdown]
# ![Iris Flowers](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Machine+Learning+R/iris-machinelearning.png)

# %%
import pandas as pd

# %%
# go to github, click RAW to get the raw data
pd.read_csv("https://raw.githubusercontent.com/illinois-cse/data-fa14/gh-pages/data/iris.csv")
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/illinois-cse/data-fa14/gh-pages/data/iris.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# https://pandas.pydata.org/docs/user_guide/indexing.html
#
# .loc is primarily label based, but may also be used with a boolean array.
# .iloc is primarily integer position based (from 0 to length-1 of the axis), but may also be used with a boolean array.

# %%
df['species'] # returns dataseries, not dataframe
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
df[['sepal_length', 'species']] #returns dataframe
# Out:
#      sepal_length    species
# 0             5.1     setosa
# 1             4.9     setosa
# 2             4.7     setosa
# 3             4.6     setosa
# 4             5.0     setosa
# ..            ...        ...
# 145           6.7  virginica
# 146           6.3  virginica
# 147           6.5  virginica
# 148           6.2  virginica
# 149           5.9  virginica
#
# [150 rows x 2 columns]

# %%
# we can select rows

df[2:6] # rows 2-6, inclusive of 2, exclusive of 6
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
df[['sepal_length', 'species']][2:6]
# Out:
#    sepal_length species
# 2           4.7  setosa
# 3           4.6  setosa
# 4           5.0  setosa
# 5           5.4  setosa

# %%
# to slice, use .loc (uses labels) and .iloc (uses positions)
df.loc[2:6]  # includes row 6
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa

# %%
df.loc[:, 'species'] # all rows and species column
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
df.loc[:, ['sepal_length', 'species']]
# Out:
#      sepal_length    species
# 0             5.1     setosa
# 1             4.9     setosa
# 2             4.7     setosa
# 3             4.6     setosa
# 4             5.0     setosa
# ..            ...        ...
# 145           6.7  virginica
# 146           6.3  virginica
# 147           6.5  virginica
# 148           6.2  virginica
# 149           5.9  virginica
#
# [150 rows x 2 columns]

# %%
df.loc[2:6, ['sepal_length', 'species']]
# Out:
#    sepal_length species
# 2           4.7  setosa
# 3           4.6  setosa
# 4           5.0  setosa
# 5           5.4  setosa
# 6           4.6  setosa

# %%
df.loc[2:6, :] # all columns
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa

# %%
newdf = df.loc[2:6, :]

# %%
newdf # theres a mixmatch between the position 0 (2) and label 2
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa

# %%
df.iloc[2:6,:] # wont go as far as 6
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
df.iloc[2,:] # right syntax
# Out:
# sepal_length       4.7
# sepal_width        3.2
# petal_length       1.3
# petal_width        0.2
# species         setosa
# Name: 2, dtype: object

# %%
df.iloc[2] # at index location 2 (first row is 0)
# Out:
# sepal_length       4.7
# sepal_width        3.2
# petal_length       1.3
# petal_width        0.2
# species         setosa
# Name: 2, dtype: object

# %%
df.iloc[0]
# Out:
# sepal_length       5.1
# sepal_width        3.5
# petal_length       1.4
# petal_width        0.2
# species         setosa
# Name: 0, dtype: object

# %%
df.iloc[2,:] # right syntax
# Out:
# sepal_length       4.7
# sepal_width        3.2
# petal_length       1.3
# petal_width        0.2
# species         setosa
# Name: 2, dtype: object

# %%
df.iloc[2:9,3] # rows 2-9, column 3
# Out:
# 2    0.2
# 3    0.2
# 4    0.2
# 5    0.4
# 6    0.3
# 7    0.2
# 8    0.2
# Name: petal_width, dtype: float64

# %%
# if u want even /odd
df.iloc[1:12:2, :] # increments of 2
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 1            4.9          3.0           1.4          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 11           4.8          3.4           1.6          0.2  setosa

# %%
df.at[2,'species'] # row 2, takes label species for column
# Out:
# 'setosa'

# %% [markdown]
# ## Boolean selects:
#
# another way of accessing data in a dataframe
# - adds conditions to the selections

# %%
df.loc[:, 'species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
# then refine it, only take rows where the species match the string 'setosa'

df.loc[:, 'species'] =='setosa' # will return true or false
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: species, Length: 150, dtype: bool

# %%
df.loc[df.loc[:, 'species'] =='setosa'] # further subselect
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
df.loc[df.loc[:, 'species'] =='versicolor']
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %%
x = df.loc[df.loc[:, 'species'] =='versicolor']

# %%
x.loc[51, :]
# Out:
# sepal_length           6.4
# sepal_width            3.2
# petal_length           4.5
# petal_width            1.5
# species         versicolor
# Name: 51, dtype: object

# %%
x.iloc[51, :]  # will give error because there is no porition 51 in this dataset. only 0-49
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/rsalgo/Desktop/ATU/W23/PROGDAW2023/repos/myworkw23/pandaswithiris.ipynb Cell 35 line 1
# ----> <a href='vscode-notebook-cell:/home/rsalgo/Desktop/ATU/W23/PROGDAW2023/repos/myworkw23/pandaswithiris.ipynb#X66sZmlsZQ%3D%3D?line=0'>1</a> x.iloc[51, :]
#
# File ~/anaconda3/envs/base_3.11/lib/python3.11/site-packages/pandas/core/indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File ~/anaconda3/envs/base_3.11/lib/python3.11/site-packages/pandas/core/indexing.py:1594, in _iLocIndexer._getitem_tuple(self, tup)
# ...

# %%
x.iloc[49, :]
# Out:
# sepal_length           5.7
# sepal_width            2.8
# petal_length           4.1
# petal_width            1.3
# species         versicolor
# Name: 99, dtype: object

# %%
df.loc[df.loc[:, 'petal_width'] == 0.2]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 14           5.8          4.0           1.2          0.2  setosa
# 20           5.4          3.4           1.7          0.2  setosa
# 22           4.6          3.6           1.0          0.2  setosa
# 24           4.8          3.4           1.9          0.2  setosa
# ...

# %%
df.loc[df.loc[:, 'petal_width'] >= 1.6] # greater than or equal to
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 56            6.3          3.3           4.7          1.6  versicolor
# 70            5.9          3.2           4.8          1.8  versicolor
# 77            6.7          3.0           5.0          1.7  versicolor
# 83            6.0          2.7           5.1          1.6  versicolor
# 85            6.0          3.4           4.5          1.6  versicolor
# 100           6.3          3.3           6.0          2.5   virginica
# 101           5.8          2.7           5.1          1.9   virginica
# 102           7.1          3.0           5.9          2.1   virginica
# 103           6.3          2.9           5.6          1.8   virginica
# 104           6.5          3.0           5.8          2.2   virginica
# 105           7.6          3.0           6.6          2.1   virginica
# 106           4.9          2.5           4.5          1.7   virginica
# ...

# %% [markdown]
# ## Summary statistics

# %%
df.head() # displays first 5 rows. Files usually go corrupt at the beginning or end
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.tail() # displays last 5 rows
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
df.describe() # numeric only. will not show species, std measures spread, 50% is median
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.mean() # select valid columns first if u get error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/base_3.11/lib/python3.11/site-packages/pandas/core/nanops.py:1680, in _ensure_numeric(x)
#    1679 try:
# -> 1680     x = x.astype(np.complex128)
#    1681 except (TypeError, ValueError):
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~/anaconda3/envs/base_3.11/lib/python3.11/site-packages/pandas/core/nanops.py:1683, in _ensure_numeric(x)
#    1682 try:
# -> 1683     x = x.astype(np.float64)
#    1684 except ValueError as err:
#    1685     # GH#29941 we get here with object arrays containing strs
#
# ValueError: could not convert string to float: '...'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
x.describe() # versicolor only. more meaningful data
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     50.000000    50.000000     50.000000    50.000000
# mean       5.936000     2.770000      4.260000     1.326000
# std        0.516171     0.313798      0.469911     0.197753
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.600000     2.525000      4.000000     1.200000
# 50%        5.900000     2.800000      4.350000     1.300000
# 75%        6.300000     3.000000      4.600000     1.500000
# max        7.000000     3.400000      5.100000     1.800000

# %% [markdown]
# ## Seaborn for visualization

# %%
import seaborn as sns

# %%
sns.pairplot(df)
# Out:
# /home/rsalgo/anaconda3/envs/base_3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(df, hue='species')
# Out:
# /home/rsalgo/anaconda3/envs/base_3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
