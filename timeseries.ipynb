# %% [markdown]
# # Time Series
#
# https://docs.python.org/3/library/datetime.html
#
# https://pandas.pydata.org/docs/user_guide/timeseries.html
#
# https://numpy.org/doc/stable/reference/random/generated/numpy.random.poisson.html
#
# - Poisson usually used for time series
#
# https://datahub.io/core/co2-ppm
#
# https://seaborn.pydata.org/tutorial/relational.html
#
# https://seaborn.pydata.org/generated/seaborn.lineplot.html
#
# https://data.gov.ie/
#
# https://data.gov.ie/dataset/knock-airport-hourly-data

# %%
import pandas as pd

# %%
pd.read_csv("https://datahub.io/core/co2-ppm/r/co2-mm-mlo.csv") # right click and copy link of csv file
# Out:
#            Date  Decimal Date  Average  Interpolated   Trend  Number of Days
# 0    1958-03-01      1958.208   315.71        315.71  314.62              -1
# 1    1958-04-01      1958.292   317.45        317.45  315.29              -1
# 2    1958-05-01      1958.375   317.50        317.50  314.71              -1
# 3    1958-06-01      1958.458   -99.99        317.10  314.85              -1
# 4    1958-07-01      1958.542   315.86        315.86  314.98              -1
# ..          ...           ...      ...           ...     ...             ...
# 722  2018-05-01      2018.375   411.24        411.24  407.91              24
# 723  2018-06-01      2018.458   410.79        410.79  408.49              29
# 724  2018-07-01      2018.542   408.71        408.71  408.32              27
# 725  2018-08-01      2018.625   406.99        406.99  408.90              30
# 726  2018-09-01      2018.708   405.51        405.51  409.02              29
#
# [727 rows x 6 columns]

# %%
# store it in pandas dataframe

df = pd.read_csv("https://datahub.io/core/co2-ppm/r/co2-mm-mlo.csv")

# %%
# index out Date column
# will output dtype:object (still generic. Not yet recognized as date time)

df["Date"]
# Out:
# 0      1958-03-01
# 1      1958-04-01
# 2      1958-05-01
# 3      1958-06-01
# 4      1958-07-01
#           ...
# 722    2018-05-01
# 723    2018-06-01
# 724    2018-07-01
# 725    2018-08-01
# 726    2018-09-01
# Name: Date, Length: 727, dtype: object

# %%
# convert into date time
# will output dtype:datetime64
pd.to_datetime(df["Date"])
# Out:
# 0     1958-03-01
# 1     1958-04-01
# 2     1958-05-01
# 3     1958-06-01
# 4     1958-07-01
#          ...
# 722   2018-05-01
# 723   2018-06-01
# 724   2018-07-01
# 725   2018-08-01
# 726   2018-09-01
# Name: Date, Length: 727, dtype: datetime64[ns]

# %%
df['datetime'] = pd.to_datetime(df["Date"])

# %%
df # will output new column datetime
# Out:
#            Date  Decimal Date  Average  Interpolated   Trend  Number of Days  \
# 0    1958-03-01      1958.208   315.71        315.71  314.62              -1
# 1    1958-04-01      1958.292   317.45        317.45  315.29              -1
# 2    1958-05-01      1958.375   317.50        317.50  314.71              -1
# 3    1958-06-01      1958.458   -99.99        317.10  314.85              -1
# 4    1958-07-01      1958.542   315.86        315.86  314.98              -1
# ..          ...           ...      ...           ...     ...             ...
# 722  2018-05-01      2018.375   411.24        411.24  407.91              24
# 723  2018-06-01      2018.458   410.79        410.79  408.49              29
# 724  2018-07-01      2018.542   408.71        408.71  408.32              27
# 725  2018-08-01      2018.625   406.99        406.99  408.90              30
# 726  2018-09-01      2018.708   405.51        405.51  409.02              29
#
#       datetime
# 0   1958-03-01
# ...

# %%
import seaborn as sns

# https://seaborn.pydata.org/tutorial/relational.html

# https://seaborn.pydata.org/generated/seaborn.lineplot.html

# %%
sns.lineplot(data=df, x="datetime", y="Interpolated")
sns.lineplot(data=df, x="datetime", y="Trend")
# Out:
# <Axes: xlabel='datetime', ylabel='Interpolated'>

# %% [markdown]
# https://data.gov.ie/dataset/knock-airport-hourly-data

# %%
df = pd.read_csv("https://cli.fusio.net/cli/climate_data/webdata/hly4935.csv") # will get error bc of description lines 1-23
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /home/rsalgo/Desktop/ATU/W23/PROGDAW2023/repos/myworkw23/timeseries.ipynb Cell 12 line 1
# ----> <a href='vscode-notebook-cell:/home/rsalgo/Desktop/ATU/W23/PROGDAW2023/repos/myworkw23/timeseries.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv("https://cli.fusio.net/cli/climate_data/webdata/hly4935.csv") # will get error bc of description lines 1-23
#
# ...

# %%
# So, skip description rows
# https://stackoverflow.com/questions/20637439/skip-rows-during-csv-import-pandas

df = pd.read_csv("https://cli.fusio.net/cli/climate_data/webdata/hly4935.csv", skiprows=23, low_memory=False) # means just use high memory/all the memory u need

# will get warning that some columns have mixed types: DtypeWarning: Columns (2,10,12,14,15,16,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False

# %%
df
# Out:
#                      date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  \
# 0       10-apr-1996 14:00    0  0.0      0  11.5      0   8.1    3.9    0.0
# 1       31-jul-1996 08:00    0  0.0      0  11.5      0  11.1   10.7    0.0
# 2       31-jul-1996 09:00    0  0.0      0  11.6      0  10.7    9.8    0.0
# 3       31-jul-1996 10:00    0  0.0      0  12.9      0  11.3    9.8    0.0
# 4       31-jul-1996 11:00    0  0.0      0  14.5      0  10.8    7.0    0.0
# ...                   ...  ...  ...    ...   ...    ...   ...    ...    ...
# 238141  30-sep-2023 20:00    0  0.0      0  13.7      0  13.7   13.6   15.7
# 238142  30-sep-2023 21:00    0  0.0      0  13.6      0  13.5   13.4   15.4
# 238143  30-sep-2023 22:00    0  0.0      0  13.6      0  13.6   13.5   15.6
# 238144  30-sep-2023 23:00    0  0.1      0  13.7      0  13.7   13.6   15.7
# 238145  01-oct-2023 00:00    0  0.0      0  13.8      0  13.8   13.8   15.8
#
# ...

# %%
df['date']
# Out:
# 0         10-apr-1996 14:00
# 1         31-jul-1996 08:00
# 2         31-jul-1996 09:00
# 3         31-jul-1996 10:00
# 4         31-jul-1996 11:00
#                 ...
# 238141    30-sep-2023 20:00
# 238142    30-sep-2023 21:00
# 238143    30-sep-2023 22:00
# 238144    30-sep-2023 23:00
# 238145    01-oct-2023 00:00
# Name: date, Length: 238146, dtype: object

# %%
pd.to_datetime(df["date"])
# Out:
# /tmp/ipykernel_18810/962263542.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df["date"])
# 0        1996-04-10 14:00:00
# 1        1996-07-31 08:00:00
# 2        1996-07-31 09:00:00
# 3        1996-07-31 10:00:00
# 4        1996-07-31 11:00:00
#                  ...
# 238141   2023-09-30 20:00:00
# 238142   2023-09-30 21:00:00
# 238143   2023-09-30 22:00:00
# 238144   2023-09-30 23:00:00
# 238145   2023-10-01 00:00:00
# Name: date, Length: 238146, dtype: datetime64[ns]

# %%
df['datetime'] = pd.to_datetime(df["date"])
# Out:
# /tmp/ipykernel_18810/1688172570.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['datetime'] = pd.to_datetime(df["date"])

# %%
df
# Out:
#                      date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  \
# 0       10-apr-1996 14:00    0  0.0      0  11.5      0   8.1    3.9    0.0
# 1       31-jul-1996 08:00    0  0.0      0  11.5      0  11.1   10.7    0.0
# 2       31-jul-1996 09:00    0  0.0      0  11.6      0  10.7    9.8    0.0
# 3       31-jul-1996 10:00    0  0.0      0  12.9      0  11.3    9.8    0.0
# 4       31-jul-1996 11:00    0  0.0      0  14.5      0  10.8    7.0    0.0
# ...                   ...  ...  ...    ...   ...    ...   ...    ...    ...
# 238141  30-sep-2023 20:00    0  0.0      0  13.7      0  13.7   13.6   15.7
# 238142  30-sep-2023 21:00    0  0.0      0  13.6      0  13.5   13.4   15.4
# 238143  30-sep-2023 22:00    0  0.0      0  13.6      0  13.6   13.5   15.6
# 238144  30-sep-2023 23:00    0  0.1      0  13.7      0  13.7   13.6   15.7
# 238145  01-oct-2023 00:00    0  0.0      0  13.8      0  13.8   13.8   15.8
#
# ...

# %%
# lets say we only want to do first 1000 rows
# https://stackoverflow.com/questions/15008970/way-to-read-first-few-lines-for-pandas-dataframe

df = pd.read_csv("https://cli.fusio.net/cli/climate_data/webdata/hly4935.csv", skiprows=23, nrows=1000, low_memory=False)

# %%
df
# Out:
#                   date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  \
# 0    10-apr-1996 14:00    0  0.0      0  11.5      0   8.1    3.9    0.0
# 1    31-jul-1996 08:00    0  0.0      0  11.5      0  11.1   10.7    0.0
# 2    31-jul-1996 09:00    0  0.0      0  11.6      0  10.7    9.8    0.0
# 3    31-jul-1996 10:00    0  0.0      0  12.9      0  11.3    9.8    0.0
# 4    31-jul-1996 11:00    0  0.0      0  14.5      0  10.8    7.0    0.0
# ..                 ...  ...  ...    ...   ...    ...   ...    ...    ...
# 995  10-sep-1996 18:00    0  0.0      0  13.7      0  12.3   11.1   13.2
# 996  10-sep-1996 19:00    0  0.0      0  12.8      0  12.0   11.3   13.4
# 997  10-sep-1996 20:00    0  0.0      0  12.4      0  11.7   11.1   13.2
# 998  10-sep-1996 21:00    0  0.0      0  12.2      0  11.6   11.1   13.2
# 999  10-sep-1996 22:00    0  0.0      0  12.0      0  11.4   10.9   13.0
#
#      rhum  ... ind.3  wdsp ind.4  wddir  ww   w  sun    vis clht clamt
# ...

# %%
df['date']
# Out:
# 0      10-apr-1996 14:00
# 1      31-jul-1996 08:00
# 2      31-jul-1996 09:00
# 3      31-jul-1996 10:00
# 4      31-jul-1996 11:00
#              ...
# 995    10-sep-1996 18:00
# 996    10-sep-1996 19:00
# 997    10-sep-1996 20:00
# 998    10-sep-1996 21:00
# 999    10-sep-1996 22:00
# Name: date, Length: 1000, dtype: object

# %%
pd.to_datetime(df["date"])
# Out:
# /tmp/ipykernel_18810/962263542.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   pd.to_datetime(df["date"])
# 0     1996-04-10 14:00:00
# 1     1996-07-31 08:00:00
# 2     1996-07-31 09:00:00
# 3     1996-07-31 10:00:00
# 4     1996-07-31 11:00:00
#               ...
# 995   1996-09-10 18:00:00
# 996   1996-09-10 19:00:00
# 997   1996-09-10 20:00:00
# 998   1996-09-10 21:00:00
# 999   1996-09-10 22:00:00
# Name: date, Length: 1000, dtype: datetime64[ns]

# %%
df['datetime'] = pd.to_datetime(df["date"])
# Out:
# /tmp/ipykernel_18810/1688172570.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['datetime'] = pd.to_datetime(df["date"])

# %%
df
# Out:
#                   date  ind rain  ind.1  temp  ind.2  wetb  dewpt  vappr  \
# 0    10-apr-1996 14:00    0  0.0      0  11.5      0   8.1    3.9    0.0
# 1    31-jul-1996 08:00    0  0.0      0  11.5      0  11.1   10.7    0.0
# 2    31-jul-1996 09:00    0  0.0      0  11.6      0  10.7    9.8    0.0
# 3    31-jul-1996 10:00    0  0.0      0  12.9      0  11.3    9.8    0.0
# 4    31-jul-1996 11:00    0  0.0      0  14.5      0  10.8    7.0    0.0
# ..                 ...  ...  ...    ...   ...    ...   ...    ...    ...
# 995  10-sep-1996 18:00    0  0.0      0  13.7      0  12.3   11.1   13.2
# 996  10-sep-1996 19:00    0  0.0      0  12.8      0  12.0   11.3   13.4
# 997  10-sep-1996 20:00    0  0.0      0  12.4      0  11.7   11.1   13.2
# 998  10-sep-1996 21:00    0  0.0      0  12.2      0  11.6   11.1   13.2
# 999  10-sep-1996 22:00    0  0.0      0  12.0      0  11.4   10.9   13.0
#
#      rhum  ... wdsp  ind.4 wddir  ww   w  sun    vis  clht clamt  \
# ...

# %%
sns.lineplot(data=df, x="datetime", y="temp") # will show no data on some days after first line
# Out:
# <Axes: xlabel='datetime', ylabel='temp'>

# %%
# so get only from row 1 onwards

sns.lineplot(data=df[1:], x="datetime", y="temp")
# Out:
# <Axes: xlabel='datetime', ylabel='temp'>

# %% [markdown]
# # Synthesizing Data

# %%
import pandas as pd
